# %% [markdown]
# # content-based filtering

# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('./temp/cleaned_movies_metadata.csv')
ratings = pd.read_csv('./IMDB/ratings_small.csv')

# %%
cond = ~ratings['movieId'].isin(movies['id'])
ratings.drop(ratings[cond].index, inplace=True)

# %%
ratings.shape
# Out:
# (44934, 4)

# %%
movies[movies.id == 4912]
# Out:
#         id  adult                            title  video  has_collection  \
# 2129  4912      0  Confessions of a Dangerous Mind      0               0
# 2130  4912      0  Confessions of a Dangerous Mind      0               0
#
#       std_budget  std_revenue  lang_ab  lang_af  lang_am  ...  \
# 2129    1.342821     0.197759        0        0        0  ...
# 2130    1.342821     0.197759        0        0        0  ...
#
#       genre_{'id': 35, 'name': 'Comedy'}  genre_{'id': 36, 'name': 'History'}  \
# 2129                                   1                                    0
# 2130                                   1                                    0
#
#       genre_{'id': 37, 'name': 'Western'}  \
# 2129                                    0
# 2130                                    0
#
#       genre_{'id': 53, 'name': 'Thriller'}  genre_{'id': 80, 'name': 'Crime'}  \
# 2129                                     1                                  1
# 2130                                     1                                  1
#
#       genre_{'id': 878, 'name': 'Science Fiction'}  \
# 2129                                             0
# 2130                                             0
#
#       genre_{'id': 9648, 'name': 'Mystery'}  \
# 2129                                      0
# 2130                                      0
#
#       genre_{'id': 99, 'name': 'Documentary'}  norm_vote_avg  std_vote_cnt
# 2129                                        0           0.66      3.444652
# 2130                                        0           0.66      3.444652
#
# [2 rows x 138 columns]

# %%
movies = movies[movies.index != 2129]

# %%
movies.shape
# Out:
# (45013, 138)

# %%
movies['b'] = 1 # bias value
movies = movies[(movies.id.isin(ratings.movieId))]
movies.set_index('id', inplace=True)
movies.drop('title', axis=1, inplace=True)
ratings.drop('timestamp', axis=1, inplace=True)

# %%
ratings.pivot(index='userId', columns='movieId', values='rating')#.fillna(0)
# Out:
# movieId  2       3       5       6       11      12      13      14      \
# userId
# 1           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     4.0     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 667         NaN     NaN     NaN     4.0     3.0     NaN     NaN     NaN
# 668         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 669         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 670         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 671         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  15      16      ...  134158  134368  134569  134881  135536  140174  \
# userId                   ...
# 1           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...  ...     ...     ...     ...     ...     ...     ...
# 667         NaN     2.0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 668         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 669         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 670         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 671         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  142507  148652  158238  160718
# userId
# 1           NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...
# 667         NaN     NaN     NaN     NaN
# 668         NaN     NaN     NaN     NaN
# 669         NaN     NaN     NaN     NaN
# 670         NaN     NaN     NaN     NaN
# 671         NaN     NaN     NaN     NaN
#
# [671 rows x 2817 columns]

# %%
user_ratings = ratings.pivot(index='userId', columns='movieId', values='rating').values#.fillna(0)

# %%
movies
# Out:
#         adult  video  has_collection  std_budget  std_revenue  lang_ab  \
# id
# 2           0      0               0   -0.203941    -0.149376        0
# 3           0      0               0   -0.203941    -0.149376        0
# 5           0      0               0   -0.217417    -0.259376        0
# 6           0      0               0   -0.203941    -0.134609        0
# 11          0      0               1    0.202647    12.016790        0
# ...       ...    ...             ...         ...          ...      ...
# 140174      0      0               0   -0.203941    -0.149376        0
# 142507      0      0               0   -0.203941    -0.149376        0
# 148652      0      0               0   -0.203941    -0.149376        0
# 158238      0      0               0   -0.203941    -0.149376        0
# 160718      0      0               0   -0.203941    -0.149376        0
#
#         lang_af  lang_am  lang_ar  lang_ay  ...  \
# id                                          ...
# 2             0        0        0        0  ...
# 3             0        0        0        0  ...
# 5             0        0        0        0  ...
# 6             0        0        0        0  ...
# 11            0        0        0        0  ...
# ...         ...      ...      ...      ...  ...
# 140174        0        0        0        0  ...
# 142507        0        0        0        0  ...
# 148652        0        0        0        0  ...
# 158238        0        0        0        0  ...
# 160718        0        0        0        0  ...
#
#         genre_{'id': 36, 'name': 'History'}  \
# id
# 2                                         0
# 3                                         0
# 5                                         0
# 6                                         0
# 11                                        0
# ...                                     ...
# 140174                                    0
# 142507                                    0
# 148652                                    0
# 158238                                    0
# 160718                                    0
#
#         genre_{'id': 37, 'name': 'Western'}  \
# id
# 2                                         0
# 3                                         0
# 5                                         0
# 6                                         0
# 11                                        0
# ...                                     ...
# 140174                                    0
# 142507                                    0
# 148652                                    0
# 158238                                    0
# 160718                                    0
#
#         genre_{'id': 53, 'name': 'Thriller'}  \
# id
# 2                                          0
# 3                                          0
# 5                                          0
# 6                                          1
# 11                                         0
# ...                                      ...
# 140174                                     1
# 142507                                     0
# 148652                                     1
# 158238                                     0
# 160718                                     0
#
#         genre_{'id': 80, 'name': 'Crime'}  \
# id
# 2                                       1
# 3                                       0
# 5                                       1
# 6                                       1
# 11                                      0
# ...                                   ...
# 140174                                  0
# 142507                                  0
# 148652                                  0
# 158238                                  0
# 160718                                  0
#
#         genre_{'id': 878, 'name': 'Science Fiction'}  \
# id
# 2                                                  0
# 3                                                  0
# 5                                                  0
# 6                                                  0
# 11                                                 1
# ...                                              ...
# 140174                                             0
# 142507                                             0
# 148652                                             0
# 158238                                             0
# 160718                                             0
#
#         genre_{'id': 9648, 'name': 'Mystery'}  \
# id
# 2                                           0
# 3                                           0
# 5                                           0
# 6                                           0
# 11                                          0
# ...                                       ...
# 140174                                      0
# 142507                                      0
# 148652                                      0
# 158238                                      0
# 160718                                      0
#
#         genre_{'id': 99, 'name': 'Documentary'}  norm_vote_avg  std_vote_cnt  \
# id
# 2                                             0           0.71      3.705611
# 3                                             0           0.71      3.705611
# 5                                             0           0.65      3.392460
# 6                                             0           0.64      3.340269
# 11                                            0           0.81      4.227528
# ...                                         ...            ...           ...
# 140174                                        0           0.34      1.774518
# 142507                                        0           0.35      1.826709
# 148652                                        0           0.39      2.035476
# 158238                                        0           0.82      4.279719
# 160718                                        0           0.00      0.000000
#
#         b
# id
# 2       1
# 3       1
# 5       1
# 6       1
# 11      1
# ...    ..
# 140174  1
# 142507  1
# 148652  1
# 158238  1
# 160718  1
#
# [2817 rows x 137 columns]

# %%
print(movies.shape)
print(user_ratings.shape)
# Out:
# (2817, 137)
# (671, 2817)

# %%
'''
a =  movies.index.values
b =  ratings.pivot(index='userId', columns='movieId', values='rating').columns.values

for i in range(1680):
    # if a[i]-b[i] != 0:
        print('bingo', i, a[i], b[i])
'''
# Out:
# "\na =  movies.index.values\nb =  ratings.pivot(index='userId', columns='movieId', values='rating').columns.values\n\nfor i in range(1680):\n    # if a[i]-b[i] != 0:\n        print('bingo', i, a[i], b[i])\n"

# %%
movie_mat = movies.values.T
movie_mat.shape
# Out:
# (137, 2817)

# %%
user_mat = np.random.rand(ratings.userId.nunique(),movie_mat.shape[0])
user_mat.shape
# Out:
# (671, 137)

# %% [markdown]
# # ------------------------------

# %%
def cal_cost(index):
    u = user_mat[index]#.reshape((-1, 1))
    t = user_ratings[index] # target
    y = u.dot(movie_mat)
    diff = y - t
    diff2 = np.power(diff, 2)
    # n = np.argwhere(~np.isnan(u)).size
    n = np.count_nonzero(~np.isnan(t))
    if n == 0:
        return 'Unknown'
    return np.nansum(diff2)/(2 * n)

# %%
from sklearn.linear_model import LinearRegression

# %%
for i in range(user_mat.shape[0]):
    # index of all rated values for this user
    rated_indexes = np.argwhere(~np.isnan(user_ratings[i])).T.tolist()[0]
    
    y = user_ratings[i, rated_indexes]
    x = movie_mat[:-1, rated_indexes] # the last one is b and shouldn't be used in w estimation

    lr_model = LinearRegression()
    lr_model.fit(x.T, y)
    w = lr_model.coef_
    b = lr_model.intercept_
    
    user_mat[i] = a = np.append(w, b)
    
    print('for: ', i, '  the cost is:  ', cal_cost(i))
# Out:
# for:  0   the cost is:   8.217301096052207e-32
# for:  1   the cost is:   0.12552498583091784
# for:  2   the cost is:   8.67746995743113e-30
# for:  3   the cost is:   2.11519608245509
# for:  4   the cost is:   0.02400896588484781
# for:  5   the cost is:   1.0500010669493467e-29
# for:  6   the cost is:   0.10798361766804375
# for:  7   the cost is:   0.0903149436816564
# for:  8   the cost is:   3.405755254271484e-30
# for:  9   the cost is:   2.0364819916330524e-29
# for:  10   the cost is:   5.763614988771018e-29
# for:  11   the cost is:   5.626434397532217e-30
# for:  12   the cost is:   2.8020996737538025e-30
# for:  13   the cost is:   4.226040563683992e-31
# for:  14   the cost is:   0.6756303267685293
# for:  15   the cost is:   5.9164567891575885e-31
# for:  16   the cost is:   0.44235633803265434
# for:  17   the cost is:   0.007753530156823389
# for:  18   the cost is:   0.32545254349468217
# for:  19   the cost is:   0.32161011482388185
# for:  20   the cost is:   0.11845173625694033
# for:  21   the cost is:   0.25610218710369537
# for:  22   the cost is:   0.3130193719980269
# for:  23   the cost is:   7.836018325195384e-30
# for:  24   the cost is:   1.4016848101434144e-29
# for:  25   the cost is:   0.18491088843493667
# for:  26   the cost is:   3.47944006409982e-30
# for:  27   the cost is:   0.0024754663415687645
# for:  28   the cost is:   1.4791141972893971e-31
# for:  29   the cost is:   0.42627043290253824
# for:  30   the cost is:   1.932709217791479e-30
# for:  31   the cost is:   0.03444754211646788
# for:  32   the cost is:   0.2886681545663763
# for:  33   the cost is:   0.846045069221188
# for:  34   the cost is:   4.6838616247497576e-30
# for:  35   the cost is:   0.1645435055307425
# for:  36   the cost is:   9.94293432622317e-31
# for:  37   the cost is:   0.003973176043038576
# for:  38   the cost is:   0.05071473129050314
# for:  39   the cost is:   2.7306723642265793e-31
# for:  40   the cost is:   0.07280153472343029
# for:  41   the cost is:   1.9873226650760105e-30
# for:  42   the cost is:   0.1840670288585747
# for:  43   the cost is:   2.4750510901309247e-30
# for:  44   the cost is:   2.465190328815662e-30
# for:  45   the cost is:   2.8685851098945885e-31
# for:  46   the cost is:   1.4168959742808368e-28
# for:  47   the cost is:   0.3617838249578104
# for:  48   the cost is:   0.1352109939303787
# for:  49   the cost is:   0.00928277142312725
# for:  50   the cost is:   8.743208366199548e-31
# for:  51   the cost is:   1.89351269156331e-29
# for:  52   the cost is:   3.618140882600218e-30
# for:  53   the cost is:   1.2678121691051976e-31
# for:  54   the cost is:   1.1216615996111262e-29
# for:  55   the cost is:   0.34285346028945324
# for:  56   the cost is:   0.46717595953901275
# for:  57   the cost is:   3.2434135642541477e-28
# for:  58   the cost is:   0.2521681289799924
# for:  59   the cost is:   1.762696091666261e-29
# for:  60   the cost is:   0.2041024475948966
# for:  61   the cost is:   4.141519752410312e-31
# for:  62   the cost is:   0.22396753355822221
# for:  63   the cost is:   4.3781780239766154e-30
# for:  64   the cost is:   5.127595883936577e-31
# for:  65   the cost is:   4.8241878434669565e-30
# for:  66   the cost is:   0.27486639335853097
# for:  67   the cost is:   0.04116406883954269
# for:  68   the cost is:   0.02996132894479333
# for:  69   the cost is:   0.15806910069659352
# for:  70   the cost is:   1.9721522630525295e-31
# for:  71   the cost is:   0.034498150441546034
# for:  72   the cost is:   0.42032269134225086
# for:  73   the cost is:   3.1554436208840472e-30
# for:  74   the cost is:   0.3584393878490239
# for:  75   the cost is:   2.834968878138011e-31
# for:  76   the cost is:   0.2205250881756108
# for:  77   the cost is:   0.25700085370047027
# for:  78   the cost is:   1.8459345182171675e-30
# for:  79   the cost is:   1.2724034230509283e-29
# for:  80   the cost is:   0.041251128875989126
# for:  81   the cost is:   1.6071726175702746e-28
# for:  82   the cost is:   0.3101748535068899
# for:  83   the cost is:   1.771855548836257e-30
# for:  84   the cost is:   0.3795932779839637
# for:  85   the cost is:   0.3525875361511892
# for:  86   the cost is:   9.885413218550804e-30
# for:  87   the cost is:   0.28528943028816556
# for:  88   the cost is:   0.007956633787883182
# for:  89   the cost is:   4.674617161016699e-30
# for:  90   the cost is:   0.002003207876829624
# for:  91   the cost is:   0.387454376126943
# for:  92   the cost is:   0.06585820272433739
# for:  93   the cost is:   0.2626462099028797
# for:  94   the cost is:   0.2622205642312765
# for:  95   the cost is:   1.345823906407226e-29
# for:  96   the cost is:   0.10976099505264737
# for:  97   the cost is:   9.224293994004786e-30
# for:  98   the cost is:   8.438583589949697
# for:  99   the cost is:   3.106139814307734e-30
# for:  100   the cost is:   2.8340558446828942e-30
# for:  101   the cost is:   0.31865968970168834
# for:  102   the cost is:   0.12793425564394942
# for:  103   the cost is:   1.1551177540736244e-30
# for:  104   the cost is:   0.16346909295932713
# for:  105   the cost is:   4.6986527667226514e-30
# for:  106   the cost is:   1.054397120639156e-29
# for:  107   the cost is:   9.64711148676529e-30
# for:  108   the cost is:   1.844542410737366e-30
# for:  109   the cost is:   0.1607761857017317
# for:  110   the cost is:   0.3038570432015407
# for:  111   the cost is:   2.3210715095925926e-30
# for:  112   the cost is:   5.557883650420765e-31
# for:  113   the cost is:   1.0236409365367891e-29
# for:  114   the cost is:   1.1013711869047203e-29
# for:  115   the cost is:   1.6692860226551766e-30
# for:  116   the cost is:   1.143355274504704e-29
# for:  117   the cost is:   0.252539418321011
# for:  118   the cost is:   0.44099389773148756
# for:  119   the cost is:   0.22406818839209144
# for:  120   the cost is:   0.0785177820869229
# for:  121   the cost is:   0.24301266191864837
# for:  122   the cost is:   3.366525542788888e-30
# for:  123   the cost is:   5.545228127877112e-30
# for:  124   the cost is:   0.28315498056295124
# for:  125   the cost is:   0.05172842746958357
# for:  126   the cost is:   9.675872040601473e-31
# for:  127   the cost is:   0.44706399357188253
# for:  128   the cost is:   1.0142497352841581e-30
# for:  129   the cost is:   0.37165938530649456
# for:  130   the cost is:   8.515471735823244e-30
# for:  131   the cost is:   2.5781830525929067e-28
# for:  132   the cost is:   0.25996241859820807
# for:  133   the cost is:   1.4283091706128686
# for:  134   the cost is:   5.1686823894168375e-30
# for:  135   the cost is:   5.279299904171387e-30
# for:  136   the cost is:   0.15918360393182732
# for:  137   the cost is:   4.787947438633086e-30
# for:  138   the cost is:   4.520779802997337e-30
# for:  139   the cost is:   1.6528514204630724e-29
# for:  140   the cost is:   1.3805065841367707e-30
# for:  141   the cost is:   6.005203640994952e-30
# for:  142   the cost is:   0.022553515009773945
# for:  143   the cost is:   1.2937318845624594e-28
# for:  144   the cost is:   5.08942519497427e-29
# for:  145   the cost is:   1.6441471342239394e-29
# for:  146   the cost is:   4.0858198616144666e-26
# for:  147   the cost is:   0.08920428737485026
# for:  148   the cost is:   0.10229025468090831
# for:  149   the cost is:   0.9308413586173302
# for:  150   the cost is:   0.13436504318482914
# for:  151   the cost is:   2.1690495155667993
# for:  152   the cost is:   2.1961887601352969e-29
# for:  153   the cost is:   1.3661636585872976e-29
# for:  154   the cost is:   3.18692220508277e-29
# for:  155   the cost is:   6.59575367976457e-30
# for:  156   the cost is:   0.2053056685411829
# for:  157   the cost is:   3.944304526105059e-31
# for:  158   the cost is:   0.31120025247752325
# for:  159   the cost is:   0.027123690325637047
# for:  160   the cost is:   0.14766717418125236
# for:  161   the cost is:   2.1872961462946238e-30
# for:  162   the cost is:   4.037533542176633e-29
# for:  163   the cost is:   0.06119376706684675
# for:  164   the cost is:   0.4578115871368209
# for:  165   the cost is:   1.568619569227935e-29
# for:  166   the cost is:   3.7865323450608565e-30
# for:  167   the cost is:   0.7584757485568429
# for:  168   the cost is:   0.05231361511711523
# for:  169   the cost is:   9.100660963877819e-30
# for:  170   the cost is:   4.24560556629364e-30
# for:  171   the cost is:   6.281304957822307e-30
# for:  172   the cost is:   1.789023838626223e-30
# for:  173   the cost is:   3.060944658279447e-29
# for:  174   the cost is:   0.10121895903247898
# for:  175   the cost is:   0.22646823045985143
# for:  176   the cost is:   0.31602388757596833
# for:  177   the cost is:   0.05728983382744856
# for:  178   the cost is:   6.310887241768095e-31
# for:  179   the cost is:   1.5875825717572864e-30
# for:  180   the cost is:   2.5004073335130285e-30
# for:  181   the cost is:   0.33959579323754485
# for:  182   the cost is:   2.1641776149813283e-30
# for:  183   the cost is:   0.13353648790830908
# for:  184   the cost is:   0.4494160962645851
# for:  185   the cost is:   7.050444340412793e-30
# for:  186   the cost is:   3.9366626237568103
# for:  187   the cost is:   0.1358702866271896
# for:  188   the cost is:   0.33865311141265775
# for:  189   the cost is:   2.3705270201891404e-30
# for:  190   the cost is:   2.4569730277196098e-30
# for:  191   the cost is:   0.03876009522044206
# for:  192   the cost is:   0.06652165612467302
# for:  193   the cost is:   0.016285475896773705
# for:  194   the cost is:   0.4514337548727145
# for:  195   the cost is:   0.048008112747523105
# for:  196   the cost is:   1.2140005859276214e-29
# for:  197   the cost is:   3.2482507862041665e-29
# for:  198   the cost is:   0.15811869926437794
# for:  199   the cost is:   2.6567128903445707
# for:  200   the cost is:   0.27005040550026127
# for:  201   the cost is:   5.961651945185876e-30
# for:  202   the cost is:   2.05000037869934e-30
# for:  203   the cost is:   1.064962222048366e-30
# for:  204   the cost is:   0.10999731306487377
# for:  205   the cost is:   5.6554366366947536e-30
# for:  206   the cost is:   1.3710380121920014e-28
# for:  207   the cost is:   4.5614721754838504e-29
# for:  208   the cost is:   9.285550238538993e-31
# for:  209   the cost is:   1.3767501036357182e-29
# for:  210   the cost is:   1.3370032253929648e-30
# for:  211   the cost is:   0.27606242033518513
# for:  212   the cost is:   1.2153349434163667
# for:  213   the cost is:   0.24617106695950497
# for:  214   the cost is:   2.8004562135345918e-30
# for:  215   the cost is:   1.2180940448265624e-30
# for:  216   the cost is:   0.005696155040632075
# for:  217   the cost is:   5.337672972826955e-30
# for:  218   the cost is:   0.11095569392612077
# for:  219   the cost is:   0.4517086663386927
# for:  220   the cost is:   5.731567514496414e-31
# for:  221   the cost is:   0.03754429154052145
# for:  222   the cost is:   3.7660523023291574e-30
# for:  223   the cost is:   0.1107355792757491
# for:  224   the cost is:   2.4096114923114543e-29
# for:  225   the cost is:   5.643389552734931e-30
# for:  226   the cost is:   8.67746995743113e-31
# for:  227   the cost is:   9.244463733058732e-31
# for:  228   the cost is:   1.7749370367472766e-31
# for:  229   the cost is:   0.0006171852215560999
# for:  230   the cost is:   6.447420859979423e-31
# for:  231   the cost is:   0.4364281126243897
# for:  232   the cost is:   9.013466268914153e-30
# for:  233   the cost is:   0.034515874965055655
# for:  234   the cost is:   0.12415257385193326
# for:  235   the cost is:   0.5459642517432738
# for:  236   the cost is:   1.530390156128763e-28
# for:  237   the cost is:   6.087319980913433e-30
# for:  238   the cost is:   0.6271702089929968
# for:  239   the cost is:   0.12142805825232675
# for:  240   the cost is:   0.007633128336451008
# for:  241   the cost is:   0.16195014390633306
# for:  242   the cost is:   0.14462843076477944
# for:  243   the cost is:   5.4337566183217474e-30
# for:  244   the cost is:   0.12784357407924882
# for:  245   the cost is:   1.7828256457994868e-29
# for:  246   the cost is:   0.2045995223164447
# for:  247   the cost is:   0.06887244085721468
# for:  248   the cost is:   5.3177677093023566e-30
# for:  249   the cost is:   0.008588161082071725
# for:  250   the cost is:   0.024885217059456993
# for:  251   the cost is:   8.950537193853788e-31
# for:  252   the cost is:   4.2132526908004495
# for:  253   the cost is:   0.2298018007763653
# for:  254   the cost is:   0.06037627852358189
# for:  255   the cost is:   5.178132285677298e-30
# for:  256   the cost is:   0.07430557105778886
# for:  257   the cost is:   9.633205284910433e-30
# for:  258   the cost is:   4.018260235969529e-30
# for:  259   the cost is:   3.210225628191062e-30
# for:  260   the cost is:   5.6679656040129695e-30
# for:  261   the cost is:   0.37568042163765586
# for:  262   the cost is:   0.0918843977656185
# for:  263   the cost is:   5.252305512335487e-30
# for:  264   the cost is:   0.19410749949889666
# for:  265   the cost is:   5.5179212969311804e-05
# for:  266   the cost is:   4.733165431326071e-30
# for:  267   the cost is:   0.3467424766099809
# for:  268   the cost is:   6.371147449805811e-30
# for:  269   the cost is:   0.04020263697450532
# for:  270   the cost is:   9.764172109067924e-06
# for:  271   the cost is:   3.8518598887744717e-31
# for:  272   the cost is:   9.385983918601854e-31
# for:  273   the cost is:   1.0140149552528422e-29
# for:  274   the cost is:   0.05901712795335677
# for:  275   the cost is:   7.357644981388283e-30
# for:  276   the cost is:   1.4336029912189541e-30
# for:  277   the cost is:   1.962291501737267e-29
# for:  278   the cost is:   0.07071473313173607
# for:  279   the cost is:   3.566308675686657e-30
# for:  280   the cost is:   0.016429575910875682
# for:  281   the cost is:   0.20593048140980794
# for:  282   the cost is:   0.16223714315338733
# for:  283   the cost is:   0.01997280559686223
# for:  284   the cost is:   0.4882118606453462
# for:  285   the cost is:   2.515726730556383e-30
# for:  286   the cost is:   0.1360179003328085
# for:  287   the cost is:   0.24606919651483003
# for:  288   the cost is:   5.454233602504652e-31
# for:  289   the cost is:   0.09280391116202165
# for:  290   the cost is:   0.10335870263048304
# for:  291   the cost is:   0.10322025647511368
# for:  292   the cost is:   0.16172124108453576
# for:  293   the cost is:   0.2034988160655092
# for:  294   the cost is:   0.09716217351335756
# for:  295   the cost is:   1.553069907153867e-30
# for:  296   the cost is:   0.24894045220175046
# for:  297   the cost is:   1.4861575982288704e-30
# for:  298   the cost is:   0.2541889267809251
# for:  299   the cost is:   1.883924398652811e-30
# for:  300   the cost is:   1.1832913578315177e-30
# for:  301   the cost is:   1.9137181219250472e-30
# for:  302   the cost is:   0.18697240552229977
# for:  303   the cost is:   0.18877443994189616
# for:  304   the cost is:   1.409660139329721e-29
# for:  305   the cost is:   0.29404695738825914
# for:  306   the cost is:   3.0920530124287874e-30
# for:  307   the cost is:   0.08722249521711387
# for:  308   the cost is:   0.1357619396320507
# for:  309   the cost is:   1.4127781666230849e-29
# for:  310   the cost is:   0.417734028767514
# for:  311   the cost is:   0.47343907290126513
# for:  312   the cost is:   0.20673651451869499
# for:  313   the cost is:   9.860761315262648e-32
# for:  314   the cost is:   2.0797242046735766e-29
# for:  315   the cost is:   1.388723885232823e-30
# for:  316   the cost is:   1.0176305677351053e-29
# for:  317   the cost is:   0.027110336008730047
# for:  318   the cost is:   2.5695983898007958e-30
# for:  319   the cost is:   5.650644962398334e-30
# for:  320   the cost is:   0.03448803681172193
# for:  321   the cost is:   2.0425862724472628e-30
# for:  322   the cost is:   3.160374001541678e-30
# for:  323   the cost is:   0.01375151469443411
# for:  324   the cost is:   6.765577902416316e-31
# for:  325   the cost is:   1.3072552143662483e-29
# for:  326   the cost is:   1.0736922827328118e-27
# for:  327   the cost is:   0.09759238047499053
# for:  328   the cost is:   8.9404235925048e-31
# for:  329   the cost is:   0.17428488635113115
# for:  330   the cost is:   3.4740220633771484e-30
# for:  331   the cost is:   9.691719692715288e-30
# for:  332   the cost is:   3.162747888524983e-30
# for:  333   the cost is:   5.390549519010247e-30
# for:  334   the cost is:   3.239964432157727e-31
# for:  335   the cost is:   4.337284866757438e-30
# for:  336   the cost is:   1.0283365371631047e-30
# for:  337   the cost is:   0.08100744791104388
# for:  338   the cost is:   6.415295302753229e-30
# for:  339   the cost is:   8.823972696972175e-29
# for:  340   the cost is:   1.8625882484385e-31
# for:  341   the cost is:   0.18930538307945682
# for:  342   the cost is:   4.79574333967293e-30
# for:  343   the cost is:   0.293916843777809
# for:  344   the cost is:   0.382709115697984
# for:  345   the cost is:   1.4152604970667098
# for:  346   the cost is:   8.628166150854817e-32
# for:  347   the cost is:   0.0003485381968231953
# for:  348   the cost is:   1.314768175368353e-31
# for:  349   the cost is:   0.2538220342771224
# for:  350   the cost is:   1.8387419629048585e-30
# for:  351   the cost is:   1.6335994578951786e-30
# for:  352   the cost is:   0.29930752948164435
# for:  353   the cost is:   0.09614898925780155
# for:  354   the cost is:   0.45016345715460676
# for:  355   the cost is:   6.63136198451413e-31
# for:  356   the cost is:   1.6155871338926323e-28
# for:  357   the cost is:   0.8564429253432609
# for:  358   the cost is:   1.758502434555172e-30
# for:  359   the cost is:   8.002397047913872e-29
# for:  360   the cost is:   0.06980145125891053
# for:  361   the cost is:   0.04720827431590405
# for:  362   the cost is:   1.3657227638548455
# for:  363   the cost is:   2.4898422321038185e-30
# for:  364   the cost is:   1.4333320911828206e-30
# for:  365   the cost is:   2.2482535798798837e-30
# for:  366   the cost is:   0.3238300603710715
# for:  367   the cost is:   8.560933687341662e-30
# for:  368   the cost is:   0.030256511597767568
# for:  369   the cost is:   0.024060196842866973
# for:  370   the cost is:   0.06619175427809867
# for:  371   the cost is:   1.0222322563488945e-29
# for:  372   the cost is:   5.755584683081116
# for:  373   the cost is:   3.3526588471893e-31
# for:  374   the cost is:   3.453059326035611e-29
# for:  375   the cost is:   1.3361331582180887e-29
# for:  376   the cost is:   9.860761315262648e-32
# for:  377   the cost is:   0.008315122625794598
# for:  378   the cost is:   4.067564042545842e-30
# for:  379   the cost is:   0.40651941479528275
# for:  380   the cost is:   0.231919417249405
# for:  381   the cost is:   0.3279000297794497
# for:  382   the cost is:   0.03705059414275907
# for:  383   the cost is:   0.17618111548046014
# for:  384   the cost is:   0.24182714240974856
# for:  385   the cost is:   0.1454397499095461
# for:  386   the cost is:   0.21221533882922042
# for:  387   the cost is:   0.45930768522833076
# for:  388   the cost is:   0.18986631942230298
# for:  389   the cost is:   0.3374944227013293
# for:  390   the cost is:   0.27314142420899307
# for:  391   the cost is:   7.2611060594206765e-31
# for:  392   the cost is:   1.8406754455156943e-30
# for:  393   the cost is:   0.37955413776285507
# for:  394   the cost is:   1.37154225566835e-30
# for:  395   the cost is:   0.43496947203838854
# for:  396   the cost is:   9.915543322569662e-31
# for:  397   the cost is:   1.4838097979157127e-30
# for:  398   the cost is:   1.8193104626659585e-29
# for:  399   the cost is:   0.11486411662686002
# for:  400   the cost is:   0.050142973035501935
# for:  401   the cost is:   0.08636309424055566
# for:  402   the cost is:   8.640492102498895e-30
# for:  403   the cost is:   8.443276876193642e-31
# for:  404   the cost is:   0.36646343736840803
# for:  405   the cost is:   2.4857335815557923e-30
# for:  406   the cost is:   0.2385603605901398
# for:  407   the cost is:   0.5270384437508053
# for:  408   the cost is:   0.1459158247931392
# for:  409   the cost is:   1.7645572879943685e-29
# for:  410   the cost is:   9.579025277683714e-31
# for:  411   the cost is:   0.34637987186484365
# for:  412   the cost is:   1.9783152388745687e-30
# for:  413   the cost is:   4.40108979291502e-30
# for:  414   the cost is:   2.286710549009408e-29
# for:  415   the cost is:   0.2714227708516481
# for:  416   the cost is:   0.15371387465775274
# for:  417   the cost is:   0.3805039871531801
# for:  418   the cost is:   2.38301731785514e-30
# for:  419   the cost is:   0.04428004510848585
# for:  420   the cost is:   0.2112231691902881
# for:  421   the cost is:   0.13069711627666925
# for:  422   the cost is:   0.3459519590154864
# for:  423   the cost is:   4.338734978715565e-31
# for:  424   the cost is:   2.0973080797462478e-30
# for:  425   the cost is:   0.14516214100090233
# for:  426   the cost is:   0.2526041130431824
# for:  427   the cost is:   0.3436127704925811
# for:  428   the cost is:   2.662405555120915e-31
# for:  429   the cost is:   0.7125454123950365
# for:  430   the cost is:   0.3382837161296556
# for:  431   the cost is:   7.268789769536465e-30
# for:  432   the cost is:   0.16227275703128088
# for:  433   the cost is:   0.36842968243253965
# for:  434   the cost is:   2.300844306894618e-31
# for:  435   the cost is:   0.037972873867395465
# for:  436   the cost is:   1.9565826399231673e-30
# for:  437   the cost is:   1.8031106405051697e-30
# for:  438   the cost is:   0.29259527515186445
# for:  439   the cost is:   6.063455175431411e-30
# for:  440   the cost is:   0.1698873560399558
# for:  441   the cost is:   0.22138982077248748
# for:  442   the cost is:   0.0
# for:  443   the cost is:   1.232595164407831e-31
# for:  444   the cost is:   5.669937756276022e-31
# for:  445   the cost is:   1.9721522630525295e-31
# for:  446   the cost is:   0.07581444512325897
# for:  447   the cost is:   0.0
# for:  448   the cost is:   3.333876444684038e-30
# for:  449   the cost is:   0.06623345957732917
# for:  450   the cost is:   3.3256121875817225e-28
# for:  451   the cost is:   0.43106200229273267
# for:  452   the cost is:   0.04348007999489384
# for:  453   the cost is:   7.428440190831194e-31
# for:  454   the cost is:   6.95473695117642e-30
# for:  455   the cost is:   8.036520471939058e-31
# for:  456   the cost is:   0.3897857558323669
# for:  457   the cost is:   0.09504790021924599
# for:  458   the cost is:   1.00579765415679e-30
# for:  459   the cost is:   0.19375223694224805
# for:  460   the cost is:   0.49188337774674024
# for:  461   the cost is:   0.08306549801540788
# for:  462   the cost is:   0.3895770839900741
# for:  463   the cost is:   8.648252886867389e-30
# for:  464   the cost is:   1.8014852402883684e-30
# for:  465   the cost is:   0.4339974036583534
# for:  466   the cost is:   0.009268385206980643
# for:  467   the cost is:   0.25945671531723347
# for:  468   the cost is:   2.8990638266872182e-30
# for:  469   the cost is:   4.0569989411366324e-30
# for:  470   the cost is:   0.09877617179178017
# for:  471   the cost is:   0.39806546471765275
# for:  472   the cost is:   2.8216947763674654e-30
# for:  473   the cost is:   3.794249462611932e-30
# for:  474   the cost is:   0.4294065573560025
# for:  475   the cost is:   2.6972082421159594e-30
# for:  476   the cost is:   1.0577907592736294e-30
# for:  477   the cost is:   1.2856915714900144e-30
# for:  478   the cost is:   0.032001280467520064
# for:  479   the cost is:   0.2125077137821599
# for:  480   the cost is:   0.22072435151823958
# for:  481   the cost is:   5.246911095851255e-30
# for:  482   the cost is:   0.0035352011908406644
# for:  483   the cost is:   1.6998435467310457e-29
# for:  484   the cost is:   3.2869204384208823e-32
# for:  485   the cost is:   0.03575149945628893
# for:  486   the cost is:   0.15228169783949852
# for:  487   the cost is:   1.2349429647209887e-30
# for:  488   the cost is:   2.258114341195146e-30
# for:  489   the cost is:   7.857794173099922e-30
# for:  490   the cost is:   0.013359000891035132
# for:  491   the cost is:   0.15846780673739413
# for:  492   the cost is:   0.1886095434854269
# for:  493   the cost is:   0.07587652904384454
# for:  494   the cost is:   6.6949379456256925e-31
# for:  495   the cost is:   0.25630189240612883
# for:  496   the cost is:   0.21590024108109623
# for:  497   the cost is:   2.834968878138011e-31
# for:  498   the cost is:   1.4220255791484028e-30
# for:  499   the cost is:   0.2512509752722347
# for:  500   the cost is:   0.16823146776872006
# for:  501   the cost is:   0.15207731001696978
# for:  502   the cost is:   1.9803695641485818e-29
# for:  503   the cost is:   6.73126706626087e-30
# for:  504   the cost is:   0.07760955837980515
# for:  505   the cost is:   2.0475580848751263e-30
# for:  506   the cost is:   7.221111363176954e-30
# for:  507   the cost is:   0.023298959351514017
# for:  508   the cost is:   0.382955886659579
# for:  509   the cost is:   0.3970965699067533
# for:  510   the cost is:   2.595948132506593e-29
# for:  511   the cost is:   1.4791141972893971e-31
# for:  512   the cost is:   5.5220263365470826e-30
# for:  513   the cost is:   1.0865463309573689
# for:  514   the cost is:   7.592786212752239e-30
# for:  515   the cost is:   0.829807964922155
# for:  516   the cost is:   0.011138739841245436
# for:  517   the cost is:   0.5286067948123525
# for:  518   the cost is:   0.06107105424539129
# for:  519   the cost is:   0.32021372996956143
# for:  520   the cost is:   6.773444799687924e-05
# for:  521   the cost is:   0.16870098134616784
# for:  522   the cost is:   0.09388193946030716
# for:  523   the cost is:   1.927250582063387e-30
# for:  524   the cost is:   0.19359442722858525
# for:  525   the cost is:   9.3129412421925e-31
# for:  526   the cost is:   0.27585488728690344
# for:  527   the cost is:   0.04767860911076161
# for:  528   the cost is:   0.39406176192688946
# for:  529   the cost is:   0.11246811307187804
# for:  530   the cost is:   0.18124931467948885
# for:  531   the cost is:   4.544524780077568e-31
# for:  532   the cost is:   0.27406455611898783
# for:  533   the cost is:   0.2526235509621748
# for:  534   the cost is:   0.5160720789874041
# for:  535   the cost is:   0.2687915407798507
# for:  536   the cost is:   0.3869487745480405
# for:  537   the cost is:   7.765349535769335e-30
# for:  538   the cost is:   1.3349953780663277e-30
# for:  539   the cost is:   2.822642926493933e-30
# for:  540   the cost is:   1.2550059855788824e-30
# for:  541   the cost is:   9.210847501302155e-30
# for:  542   the cost is:   9.038092085532164e-30
# for:  543   the cost is:   0.027012739133410988
# for:  544   the cost is:   0.40160626741140726
# for:  545   the cost is:   8.195398469475652e-07
# for:  546   the cost is:   0.5751737211545308
# for:  547   the cost is:   0.1105631737988077
# for:  548   the cost is:   9.328691069293268e-30
# for:  549   the cost is:   0.3081907701569718
# for:  550   the cost is:   0.00849201616828699
# for:  551   the cost is:   3.4331226595218436e-29
# for:  552   the cost is:   0.06315328524838801
# for:  553   the cost is:   1.3118605149805192e-29
# for:  554   the cost is:   0.13455402392607468
# for:  555   the cost is:   2.739498779949332e-29
# for:  556   the cost is:   2.9793585973972143e-30
# for:  557   the cost is:   0.11325385353075805
# for:  558   the cost is:   0.11642865956126786
# for:  559   the cost is:   0.0401744350229843
# for:  560   the cost is:   0.1701256512457298
# for:  561   the cost is:   0.057806085598299174
# for:  562   the cost is:   0.02160011203021912
# for:  563   the cost is:   0.7278380069349494
# for:  564   the cost is:   3.810198172217487e-29
# for:  565   the cost is:   1.2678121691051976e-31
# for:  566   the cost is:   5.02898827078395e-30
# for:  567   the cost is:   7.21244256202068e-29
# for:  568   the cost is:   0.12989413904747568
# for:  569   the cost is:   0.041778898173040854
# for:  570   the cost is:   2.40138540265808e-30
# for:  571   the cost is:   1.832458144419642e-30
# for:  572   the cost is:   4.417621069237666e-29
# for:  573   the cost is:   0.2625460494571004
# for:  574   the cost is:   0.42425400547815856
# for:  575   the cost is:   1.2095867213388849e-30
# for:  576   the cost is:   0.1466154012315933
# for:  577   the cost is:   3.1322418295540175e-30
# for:  578   the cost is:   9.441678959363984e-31
# for:  579   the cost is:   0.27881332166093153
# for:  580   the cost is:   1.2842191501171473e-29
# for:  581   the cost is:   0.19160042326742163
# for:  582   the cost is:   8.765121169122354e-31
# for:  583   the cost is:   0.15718141176415804
# for:  584   the cost is:   0.1981937176063509
# for:  585   the cost is:   2.3424443936933822e-29
# for:  586   the cost is:   0.17527003966664012
# for:  587   the cost is:   0.0772038153076075
# for:  588   the cost is:   7.843531286197489e-30
# for:  589   the cost is:   0.0818212303771254
# for:  590   the cost is:   6.961987510967055e-30
# for:  591   the cost is:   0.3005959955036772
# for:  592   the cost is:   0.034979657689404885
# for:  593   the cost is:   0.009401011476298266
# for:  594   the cost is:   0.7063093793635465
# for:  595   the cost is:   0.20854793898804388
# for:  596   the cost is:   0.22711482126994625
# for:  597   the cost is:   0.3538962427896163
# for:  598   the cost is:   0.14929721009848382
# for:  599   the cost is:   1.148074353134151e-30
# for:  600   the cost is:   2.9508328235923473e-29
# for:  601   the cost is:   1.6453924927600594
# for:  602   the cost is:   0.05501464511928484
# for:  603   the cost is:   6.748458525132874e-31
# for:  604   the cost is:   0.8214490200216705
# for:  605   the cost is:   2.070759876205156e-30
# for:  606   the cost is:   0.22964655939532921
# for:  607   the cost is:   0.27600246152093555
# for:  608   the cost is:   0.6213872281813925
# for:  609   the cost is:   2.010078268111232e-30
# for:  610   the cost is:   2.3665827156630354e-30
# for:  611   the cost is:   1.4263970502578007e-29
# for:  612   the cost is:   4.1661716556984686e-30
# for:  613   the cost is:   0.25468997586339864
# for:  614   the cost is:   0.1467429333993898
# for:  615   the cost is:   1.4449807927365648e-30
# for:  616   the cost is:   0.12751026329945545
# for:  617   the cost is:   9.178093224206003e-31
# for:  618   the cost is:   0.0398413036240328
# for:  619   the cost is:   0.07836240677308715
# for:  620   the cost is:   0.2475867870203401
# for:  621   the cost is:   1.4278382384500315e-29
# for:  622   the cost is:   0.012731771495025095
# for:  623   the cost is:   0.4000076802173477
# for:  624   the cost is:   1.539136222686648e-30
# for:  625   the cost is:   0.27279294434873785
# for:  626   the cost is:   0.319341985113693
# for:  627   the cost is:   1.67632942359465e-29
# for:  628   the cost is:   4.8059833610387794e-29
# for:  629   the cost is:   7.592786212752239e-31
# for:  630   the cost is:   3.934913324852428e-30
# for:  631   the cost is:   1.67632942359465e-30
# for:  632   the cost is:   3.440602229586161e-28
# for:  633   the cost is:   1.3238072065740105e-30
# for:  634   the cost is:   1.1366581741114214e-29
# for:  635   the cost is:   2.8939190816531685e-30
# for:  636   the cost is:   9.860761315262648e-31
# for:  637   the cost is:   4.300387573600654e-31
# for:  638   the cost is:   0.06012830617629377
# for:  639   the cost is:   1.1991204746797025e-29
# for:  640   the cost is:   0.18122694930694636
# for:  641   the cost is:   5.0418501333690754e-30
# for:  642   the cost is:   4.812051521848172e-30
# for:  643   the cost is:   4.4537771940602956e-30
# for:  644   the cost is:   2.8650989821568694e-30
# for:  645   the cost is:   0.2206961871140054
# for:  646   the cost is:   0.4435425049728817
# for:  647   the cost is:   0.6073428504871872
# for:  648   the cost is:   0.23223593875543394
# for:  649   the cost is:   8.165649489162735e-30
# for:  650   the cost is:   2.4272643237569595e-30
# for:  651   the cost is:   0.07118793044756291
# for:  652   the cost is:   0.01998969856534763
# for:  653   the cost is:   0.15595243951305748
# for:  654   the cost is:   0.02223616204669025
# for:  655   the cost is:   0.02014702939701325
# for:  656   the cost is:   4.759114803208341e-30
# for:  657   the cost is:   0.09257400508750331
# for:  658   the cost is:   0.21860073593635004
# for:  659   the cost is:   1.8461536462463957e-29
# for:  660   the cost is:   1.8101540414446432e-30
# for:  661   the cost is:   0.04127398915718888
# for:  662   the cost is:   0.0
# for:  663   the cost is:   0.09397038984583102
# for:  664   the cost is:   0.3283481863599816
# for:  665   the cost is:   0.014174326285946434
# for:  666   the cost is:   0.11753353845183515
# for:  667   the cost is:   4.042912139257685e-31
# for:  668   the cost is:   3.3992733552250874e-29
# for:  669   the cost is:   2.981430185908824e-30
# for:  670   the cost is:   0.03322528465795492

# %% [markdown]
# # check

# %%
r = np.argwhere(~np.isnan(user_ratings[0])).T.tolist()[0]

# %%
user_ratings[0, r]
# Out:
# array([2.5, 1. , 4. , 2. , 2. , 2.5])

# %%
b = 1.5759953750658187
user_mat.dot(movie_mat)[0][r]
# Out:
# array([2.5, 1. , 4. , 2. , 2. , 2.5])

# %% [markdown]
# ----------
# # collaborative filtering
# ----------

# %%
def cal_sim(ind1, ind2):
    user1 = user_ratings[ind1]
    user2 = user_ratings[ind2]
    dot = np.nansum(user1 * user2) # dot product ignore missign values
    u1_l = np.sqrt(np.nansum(np.power(user1, 2))) # ||user1||
    u2_l = np.sqrt(np.nansum(np.power(user2, 2))) # ||user2||
    
    if u1_l == 0 or u2_l == 0:
        return 0
        
    return dot / (u1_l * u2_l)

# %%
def sim_vector(user_index):
    no_users = user_ratings.shape[0]
    sim_vec = np.zeros(no_users)
    for i in range(no_users):
        sim_vec[i] = cal_sim(user_index, i)
        
    return sim_vec

# %%
def cal_r_s(user_index):
    sim_vec = sim_vector(user_index)
    r_s_vector = sim_vec * user_ratings.T
    return r_s_vector.T, sim_vec

# %%
user_ratings.shape
# Out:
# (671, 2817)

# %%
def col_filtering():
    no_users = user_ratings.shape[0]
    no_user_index = user_ratings.shape[1]
    new_user_ratings = np.zeros(user_ratings.shape)
    for u_ind in range(no_users):
        r_s, s = cal_r_s(u_ind)
        for i in range(no_user_index):
            r_s_sum = np.nansum(r_s[:,i])
            s_sum = np.nansum(s)
            val = r_s_sum / s_sum
            new_user_ratings[u_ind, i] = val
            
    return new_user_ratings

# %%
ss = col_filtering()

# %%
ss.shape
# Out:
# (671, 2817)

# %% [markdown]
# # check

# %%
ss[0, r]
# Out:
# array([1.4503167 , 0.75405164, 1.86921303, 1.13803393, 1.30000437,
#        1.43968368])

# %%
user_ratings[0, r]
# Out:
# array([2.5, 1. , 4. , 2. , 2. , 2.5])
